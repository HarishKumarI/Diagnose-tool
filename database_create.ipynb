# %%
from qa_app_api import db
from qa_app_api import User
from qa_app_api import Covid
import sqlalchemy
import pprint

# %%
# create database (run only once)

db.create_all()

# %%
data = {
        "current_q": "admission process where is the admin department . Get the directions",
        "answer_json": {
            "answer": [
                "Ug first-time freshman admission process for fall 2020 can be accessed through ug first-time freshman admission info website - http://admissions.fullerton.edu/prospectivestudent/admissions_ftf.php. Ug first-time freshman admission process for spring 2020 can be accessed through ug first-time freshman admission info website - http://admissions.fullerton.edu/prospectivestudent/admissions_ftf.php. Ug transfer admission process for fall 2020 can be accessed through ug transfer admission info website - http://admissions.fullerton.edu/prospectivestudent/admissions_transfers.php. Graduate admission process for international students can be accessed through admission info website for international students - https://international.fullerton.edu/admissions/masters-graduate-students/. Ug international transfer admission process can be accessed through ug international transfer info website - https://international.fullerton.edu/admissions/transfer-students/. Ug international first-time freshman admission process can be accessed through ug international first-time freshman admission info website - https://international.fullerton.edu/admissions/freshman/. Ug transfer admission process for spring 2020 can be accessed through ug transfer admission info website for spring 2020 - http://admissions.fullerton.edu/prospectivestudent/admissions_transfers.php. Graduate admission process for domestic students for fall 2020 can be accessed through website about admission info for domestic graduate students - http://admissions.fullerton.edu/prospectivestudent/admissions_graduate.php.",
                ""
            ],
            "failed_assoc_prob_list": "[]",
            "node_doc_results": [],
            "pred_tuples": [
                [
                    "access_method(fall2020_freshman_admission, X). ",
                    "access_method(spring2020_freshman_admission, X). ",
                    "access_method(fall2020_transfer_admission, X). ",
                    "access_method(grad_international_process, X). ",
                    "access_method(ug_international_transf_process, X). ",
                    "access_method(ug_international_freshman_process, X). ",
                    "access_method(spring2020_transfer_admission, X). ",
                    "access_method(fall2020_grad_admission, X). "
                ]
            ],
            "ref_exp_nodes": [
                "admission_process (\t admission process , 0.9989869 )"
            ],
            "res_dict": "{'trigger_info': [{'predicates': {5: defaultdict(<class 'list'>,\n                                                 {'admission': [(('access_method',\n                                                                  0.9999989),\n                                                                 ([('IGN',\n                                                                    0.95454377)],\n                                                                  None),\n                                                                 ([('?', 1.0)],\n                                                                  'admission'),\n                                                                 ([(False,\n                                                                    1.0)],\n                                                                  'procedure')),\n                                                                (('access_method',\n                                                                  0.9999989),\n                                                                 ([('admission_service',\n                                                                    0.019588582),\n                                                                   ('admission_state',\n                                                                    0.015136472),\n                                                                   ('admission_facility',\n                                                                    0.0064352364)],\n                                                                  'admission'),\n                                                                 ([('?', 1.0)],\n                                                                  'admission'),\n                                                                 ([(False,\n                                                                    1.0)],\n                                                                  'procedure')),\n                                                                (('access_method',\n                                                                  0.9999989),\n                                                                 ([('?',\n                                                                    1.9986368e-11)],\n                                                                  'admission'),\n                                                                 ([('?', 1.0)],\n                                                                  'admission'),\n                                                                 ([(False,\n                                                                    1.0)],\n                                                                  'procedure'))],\n                                                  'admission process': [(('access_method',\n                                                                          0.9999989),\n                                                                         ([('IGN',\n                                                                            0.89854044)],\n                                                                          None),\n                                                                         ([('?',\n                                                                            1.0)],\n                                                                          'admission '\n                                                                          'process'),\n                                                                         ([(False,\n                                                                            1.0)],\n                                                                          'procedure')),\n                                                                        (('access_method',\n                                                                          0.9999989),\n                                                                         ([('admission_process',\n                                                                            0.101356536),\n                                                                           ('admission_event',\n                                                                            3.7315516e-05),\n                                                                           ('admission_facility',\n                                                                            3.196753e-05)],\n                                                                          'admission '\n                                                                          'process'),\n                                                                         ([('?',\n                                                                            1.0)],\n                                                                          'admission '\n                                                                          'process'),\n                                                                         ([(False,\n                                                                            1.0)],\n                                                                          'procedure')),\n                                                                        (('access_method',\n                                                                          0.9999989),\n                                                                         ([(False,\n                                                                            2.0057556e-07)],\n                                                                          None),\n                                                                         ([('?',\n                                                                            1.0)],\n                                                                          'admission '\n                                                                          'process'),\n                                                                         ([(False,\n                                                                            1.0)],\n                                                                          'procedure'))],\n                                                  'procedure': [(('access_method',\n                                                                  0.9999989),\n                                                                 ([('IGN',\n                                                                    0.99999607)],\n                                                                  None),\n                                                                 ([('?', 1.0)],\n                                                                  'procedure'),\n                                                                 ([(False,\n                                                                    1.0)],\n                                                                  'procedure')),\n                                                                (('access_method',\n                                                                  0.9999989),\n                                                                 ([('admission_process',\n                                                                    3.890535e-06),\n                                                                   ('lib_policy',\n                                                                    9.984504e-10),\n                                                                   ('process_step',\n                                                                    2.6925978e-10)],\n                                                                  'procedure'),\n                                                                 ([('?', 1.0)],\n                                                                  'procedure'),\n                                                                 ([(False,\n                                                                    1.0)],\n                                                                  'procedure')),\n                                                                (('access_method',\n                                                                  0.9999989),\n                                                                 ([('?',\n                                                                    2.316047e-13)],\n                                                                  'procedure'),\n                                                                 ([('?', 1.0)],\n                                                                  'procedure'),\n                                                                 ([(False,\n                                                                    1.0)],\n                                                                  'procedure'))],\n                                                  'process': [(('access_method',\n                                                                0.9999989),\n                                                               ([('IGN',\n                                                                  0.99773633)],\n                                                                None),\n                                                               ([('?', 1.0)],\n                                                                'process'),\n                                                               ([(False, 1.0)],\n                                                                'procedure')),\n                                                              (('access_method',\n                                                                0.9999989),\n                                                               ([('admission_process',\n                                                                  0.0016331621),\n                                                                 ('process_step',\n                                                                  0.0006302642),\n                                                                 ('mode',\n                                                                  9.522462e-08)],\n                                                                'process'),\n                                                               ([('?', 1.0)],\n                                                                'process'),\n                                                               ([(False, 1.0)],\n                                                                'procedure')),\n                                                              (('access_method',\n                                                                0.9999989),\n                                                               ([(False,\n                                                                  1.8707687e-09)],\n                                                                None),\n                                                               ([('?', 1.0)],\n                                                                'process'),\n                                                               ([(False, 1.0)],\n                                                                'procedure'))]})},\n                   'trigger': 'procedure'}]}",
            "response": [
                [
                    "access_method(fall2020_freshman_admission, fall2020_freshman_admission_info_website). "
                ],
                [
                    "access_method(spring2020_freshman_admission, spring2020_freshman_admission_info_website). "
                ],
                [
                    "access_method(fall2020_transfer_admission, fall2020_transfer_admission_info_website). "
                ],
                [
                    "access_method(grad_international_process, grad_international_process_info_website). "
                ],
                [
                    "access_method(ug_international_transf_process, ug_international_transf_process_info_website). "
                ],
                [
                    "access_method(ug_international_freshman_process, ug_international_freshman_process_info_website). "
                ],
                [
                    "access_method(spring2020_transfer_admission, spring2020_transfer_admission_info_website). "
                ],
                [
                    "access_method(fall2020_grad_admission, fall2020_grad_admission_info_website). "
                ]
            ],
            "results": [
                [
                    "access_method(admission_process,?)",
                    {
                        "neg": "procedure",
                        "p": "access_method",
                        "x": "admission process",
                        "y": "admission process"
                    }
                ]
            ]
        },
        "relevant": True,
        "cmt": "too long",
        "submitted": False,
        "status": "SUCCESS",
        "timestamp": "2020-04-14 15:08:02.266475",
        "user_id": 12134,
        "username": "Harish",
        "email": "harish@cognirel.com"
    }

# %%
i = 1

# %%
# adding row in database

ans = data["answer_json"] 
record = User(
        id = i,
        question = data["current_q"],
        answer = str(ans["answer"]),
        failed_assoc_prob_list = str(ans["failed_assoc_prob_list"]),
        node_doc = str(ans["node_doc_results"]) ,
        predicate_tuples = str(ans["pred_tuples"]) ,
        ref_exp_nodes = str(ans["ref_exp_nodes"]),
        res_dict = ans["res_dict"],
        response = str(ans["response"]),
        results = str(ans["results"]),
        relevant = data["relevant"],
        comment = data["cmt"],
        submitted = data["submitted"],
        status = data["status"],
        timestamp = data["timestamp"],
        user_id = int(data['user_id']) ,
        username = data['username'],
        email = data['email'],
        state = 'Open',
        issue_type = '',
        owner = sqlalchemy.sql.null(),
        notes = sqlalchemy.sql.null()
        )
db.session.add(record)
db.session.commit()
i+= 1

# %%
j = 1

# %%
# adding row in database

ans = data["answer_json"] 
record1 = Covid(
        id = j,
        question = data["current_q"],
        answer = str(ans["answer"]),
        failed_assoc_prob_list = str(ans["failed_assoc_prob_list"]),
        node_doc = str(ans["node_doc_results"]) ,
        predicate_tuples = str(ans["pred_tuples"]) ,
        ref_exp_nodes = str(ans["ref_exp_nodes"]),
        res_dict = ans["res_dict"],
        response = str(ans["response"]),
        results = str(ans["results"]),
        relevant = data["relevant"],
        comment = data["cmt"],
        submitted = data["submitted"],
        status = data["status"],
        timestamp = data["timestamp"],
        statictics = "",
        source = "",
        source_link = "",
        img_link = "",
        user_id = int(data['user_id']) ,
        username = data['username'],
        email = data['email'],
        state = 'Open',
        issue_type = "",
        owner = sqlalchemy.sql.null(),
        notes = sqlalchemy.sql.null()
        )
db.session.add(record1)
db.session.commit()
j+= 1

# %%
# check the rows

usrs = User.query.all()
usrs
# Out:
# [<User 'Harish'>, <User 'Harish'>, <User 'Harish'>]

# %%
dir(User.query.all()[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mapper__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__table__',
#  '__tablename__',
#  '__weakref__',
#  '_decl_class_registry',
#  '_sa_class_manager',
#  '_sa_instance_state',
#  'answer',
#  'comment',
#  'email',
#  'failed_assoc_prob_list',
#  'id',
#  'issue_type',
#  'metadata',
#  'node_doc',
#  'notes',
#  'owner',
#  'predicate_tuples',
#  'query',
#  'query_class',
#  'question',
#  'ref_exp_nodes',
#  'relevant',
#  'res_dict',
#  'response',
#  'results',
#  'state',
#  'status',
#  'submitted',
#  'timestamp',
#  'user_id',
#  'username']

# %%
# view data in the row

for usr in usrs:
    pprint.pprint(vars(usr))
# Out:
# {'_sa_instance_state': <sqlalchemy.orm.state.InstanceState object at 0x7fb74a4c7828>,
#  'answer': "['Ug first-time freshman admission process for fall 2020 can be "
#            'accessed through ug first-time freshman admission info website - '
#            'http://admissions.fullerton.edu/prospectivestudent/admissions_ftf.php. '
#            'Ug first-time freshman admission process for spring 2020 can be '
#            'accessed through ug first-time freshman admission info website - '
#            'http://admissions.fullerton.edu/prospectivestudent/admissions_ftf.php. '
#            'Ug transfer admission process for fall 2020 can be accessed '
#            'through ug transfer admission info website - '
#            'http://admissions.fullerton.edu/prospectivestudent/admissions_transfers.php. '
#            'Graduate admission process for international students can be '
#            'accessed through admission info website for international students '
#            '- '
# ...

# %%
# to delete row from database

row = User.query.filter_by(id=4).first()
db.session.delete(row)
db.session.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/envs/knowledgemodel/lib/python3.6/site-packages/sqlalchemy/orm/session.py in delete(self, instance)
#    2011         try:
# -> 2012             state = attributes.instance_state(instance)
#    2013         except exc.NO_STATE as err:
#
# AttributeError: 'NoneType' object has no attribute '_sa_instance_state'
#
# The above exception was the direct cause of the following exception:
#
# UnmappedInstanceError                     Traceback (most recent call last)
# <ipython-input-9-2d9f57a5cbdf> in <module>
#       2
#       3 row = User.query.filter_by(id=4).first()
# ----> 4 db.session.delete(row)
#       5 db.session.commit()
#
# ~/anaconda3/envs/knowledgemodel/lib/python3.6/site-packages/sqlalchemy/orm/scoping.py in do(self, *args, **kwargs)
#     160 def instrument(name):
#     161     def do(self, *args, **kwargs):
# ...

# %%
# delete table from database

db.drop_all()

# %%
[cls for cls in db.Model._decl_class_registry.values()]
# Out:
# [qa_app_api.User,
# ...
#  qa_app_api.Covid]

# %%
db.Model.query_class
# Out:
# flask_sqlalchemy.BaseQuery

# %%
dir(db.Model)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_decl_class_registry',
#  'metadata',
#  'query',
#  'query_class']

# %%
import redis
import pickle

# %%
r = redis.Redis(host='localhost', port=6379, db=0)
res = r.keys()

# %%
sessionId = "d8c0d3be-440e-4ec4-af5b-ff429f6eaccb"

# %%
res = r.get('session:'+sessionId) 
result = pickle.loads(res)

# %%
for msg in result['history']:
    del msg['Developer Feedback']
    msg['developer_feedback'] = { "notes":"testing", "state":"", "issue_type": None }

# %%
result['history'][0]
# Out:
# {'msg_id': '',
#  'msg_rank': 0,
#  'message': 'Hey! What are the available variants in santro',
#  'sender': 'USER',
#  'inference_output': [{'nlu_response': {'concept2inst_dict': {'model': ['santro']},
#     'concept_nodes': ['model'],
#     'is_modified': False,
#     'original': 'What are the available variants in santro',
#     'other_ents': {},
#     'predicates': [['has_telematic_feature', 'santro', '?']],
#     'res_dict': {'0 what be the available in': {'40': {'santro': [{'X': "([('model', 0.98884684)], 'santro')",
#          'Y': '([(False, 0.9986351)], None)',
#          'pred_name': "('has_telematic_feature', 0.9996786)"},
#         {'X': "([('IGN', 0.010653707)], None)",
#          'Y': '([(False, 0.9986351)], None)',
#          'pred_name': "('has_telematic_feature', 0.9996786)"},
#         {'X': "([('model', 0.98884684)], 'santro')",
#          'Y': "([('IGN', 0.0013648492)], None)",
#          'pred_name': "('has_telematic_feature', 0.9996786)"}],
# ...

# %%
r.set('session:'+sessionId, pickle.dumps( result ) )
# Out:
# True

# %%
result['history'][1]
# Out:
# {'developer_feedback': {'issue_type': '', 'notes': '', 'state': 'Fixed'},
#  'feedback': True,
#  'feedback_text': 'got getting coruosel',
#  'inference_output': None,
#  'message': None,
#  'msg_id': '',
#  'msg_rank': 1,
#  'payload': {'bot_response': [{'content': [[[{'p': 'Sorry, I am not aware.'}]]],
#     'markdown': True,
#     'type': 'TEXT'}],
#   'footer_options': [],
#   'message_id': 1,
#   'question': 'what are the color options of ertiga',
#   'time_taken': '3 sec'},
#  'sender': 'BOT'}
